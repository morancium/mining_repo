# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Dataset:
# It is having investment and profit of 50 Starts up at USA.

# %%
Score = pd.read_csv("startupUS.csv")
Score.shape
Score.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit
# 0  165349.20       136897.80        471784.10  192261.83
# 1  162597.70       151377.59        443898.53  191792.06
# 2  153441.51       101145.55        407934.54  191050.39
# 3  144372.41       118671.85        383199.62  182901.99
# 4  142107.34        91391.77        366168.42  166187.94

# %%
#preparing the data
X = Score.drop('Profit', axis=1)
y = Score['Profit']
#X.head()
#y.head()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train.shape
#X_test.shape
# Out:
# (40, 3)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X, y)
# Out:
# LinearRegression()

# %%
# ?LinearRegression

# %%
#printing parameters:
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# 50122.19298986524
# [ 0.80571505 -0.02681597  0.02722806]

# %%
#making predictions:
y_pred = regressor.predict(X)
y_pred
# Out:
# array([192521.25289008, 189156.76823227, 182147.2790962 , 173696.70002553,
#        172139.51418327, 163580.7805712 , 158114.09666865, 160021.36304781,
#        151741.69969865, 154884.68410995, 135509.01636714, 135573.71296074,
#        129138.05418243, 127487.99166275, 149548.64633453, 146235.1599852 ,
#        116915.40540144, 130192.44720781, 129014.2268059 , 115635.21636716,
#        116639.6692309 , 117319.45164029, 114706.98171695, 109996.61522126,
#        113362.96611314, 102237.72506481, 110600.5753503 , 114408.07145684,
#        101660.02600497, 101794.98345176,  99452.37293606,  97687.85627575,
#         99001.32898549,  97915.00780465,  89039.27374116,  90511.59956753,
#         75286.17458546,  89619.5377079 ,  69697.43064804,  83729.01197692,
#         74815.95399105,  74802.55623866,  70620.41182056,  60167.03996335,
#         64611.3549157 ,  47650.64968691,  56166.20685261,  46490.58898335,
#         49171.38815763,  48215.1341113 ])

# %%
df = pd.DataFrame({'Actual': y, 'Predicted': y_pred})
df
# Out:
#        Actual      Predicted
# 0   192261.83  192521.252890
# 1   191792.06  189156.768232
# 2   191050.39  182147.279096
# 3   182901.99  173696.700026
# 4   166187.94  172139.514183
# 5   156991.12  163580.780571
# 6   156122.51  158114.096669
# 7   155752.60  160021.363048
# 8   152211.77  151741.699699
# 9   149759.96  154884.684110
# 10  146121.95  135509.016367
# 11  144259.40  135573.712961
# 12  141585.52  129138.054182
# 13  134307.35  127487.991663
# 14  132602.65  149548.646335
# 15  129917.04  146235.159985
# 16  126992.93  116915.405401
# 17  125370.37  130192.447208
# 18  124266.90  129014.226806
# 19  122776.86  115635.216367
# 20  118474.03  116639.669231
# 21  111313.02  117319.451640
# 22  110352.25  114706.981717
# 23  108733.99  109996.615221
# 24  108552.04  113362.966113
# 25  107404.34  102237.725065
# 26  105733.54  110600.575350
# 27  105008.31  114408.071457
# 28  103282.38  101660.026005
# 29  101004.64  101794.983452
# 30   99937.59   99452.372936
# 31   97483.56   97687.856276
# 32   97427.84   99001.328985
# 33   96778.92   97915.007805
# 34   96712.80   89039.273741
# 35   96479.51   90511.599568
# 36   90708.19   75286.174585
# 37   89949.14   89619.537708
# 38   81229.06   69697.430648
# 39   81005.76   83729.011977
# 40   78239.91   74815.953991
# 41   77798.83   74802.556239
# 42   71498.49   70620.411821
# 43   69758.98   60167.039963
# 44   65200.33   64611.354916
# 45   64926.08   47650.649687
# 46   49490.75   56166.206853
# 47   42559.73   46490.588983
# 48   35673.41   49171.388158
# 49   14681.40   48215.134111

# %%
# The coefficients
from sklearn.metrics import mean_squared_error, r2_score
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('R^2 Score: %.2f'
      % r2_score(y, y_pred))
# Out:
# Mean squared error: 78417126.02
# R^2 Score: 0.95

# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats


X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):           4.53e-30
# Time:                        08:38:04   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# R&D Spend           0.8057      0.045     17.846      0.000       0.715       0.897
# Administration     -0.0268      0.051     -0.526      0.602      -0.130       0.076
# Marketing Spend     0.0272      0.016      1.655      0.105      -0.006       0.060
# ==============================================================================
# Omnibus:                       14.838   Durbin-Watson:                   1.282
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               21.442
# Skew:                          -0.949   Prob(JB):                     2.21e-05
# Kurtosis:                       5.586   Cond. No.                     1.40e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X2
# Out:
#     const  R&D Spend  Administration  Marketing Spend
# 0     1.0  165349.20       136897.80        471784.10
# 1     1.0  162597.70       151377.59        443898.53
# 2     1.0  153441.51       101145.55        407934.54
# 3     1.0  144372.41       118671.85        383199.62
# 4     1.0  142107.34        91391.77        366168.42
# 5     1.0  131876.90        99814.71        362861.36
# 6     1.0  134615.46       147198.87        127716.82
# 7     1.0  130298.13       145530.06        323876.68
# 8     1.0  120542.52       148718.95        311613.29
# 9     1.0  123334.88       108679.17        304981.62
# 10    1.0  101913.08       110594.11        229160.95
# 11    1.0  100671.96        91790.61        249744.55
# 12    1.0   93863.75       127320.38        249839.44
# 13    1.0   91992.39       135495.07        252664.93
# 14    1.0  119943.24       156547.42        256512.92
# 15    1.0  114523.61       122616.84        261776.23
# 16    1.0   78013.11       121597.55        264346.06
# 17    1.0   94657.16       145077.58        282574.31
# 18    1.0   91749.16       114175.79        294919.57
# 19    1.0   86419.70       153514.11             0.00
# 20    1.0   76253.86       113867.30        298664.47
# 21    1.0   78389.47       153773.43        299737.29
# 22    1.0   73994.56       122782.75        303319.26
# 23    1.0   67532.53       105751.03        304768.73
# 24    1.0   77044.01        99281.34        140574.81
# 25    1.0   64664.71       139553.16        137962.62
# 26    1.0   75328.87       144135.98        134050.07
# 27    1.0   72107.60       127864.55        353183.81
# 28    1.0   66051.52       182645.56        118148.20
# 29    1.0   65605.48       153032.06        107138.38
# 30    1.0   61994.48       115641.28         91131.24
# 31    1.0   61136.38       152701.92         88218.23
# 32    1.0   63408.86       129219.61         46085.25
# 33    1.0   55493.95       103057.49        214634.81
# 34    1.0   46426.07       157693.92        210797.67
# 35    1.0   46014.02        85047.44        205517.64
# 36    1.0   28663.76       127056.21        201126.82
# 37    1.0   44069.95        51283.14        197029.42
# 38    1.0   20229.59        65947.93        185265.10
# 39    1.0   38558.51        82982.09        174999.30
# 40    1.0   28754.33       118546.05        172795.67
# 41    1.0   27892.92        84710.77        164470.71
# 42    1.0   23640.93        96189.63        148001.11
# 43    1.0   15505.73       127382.30         35534.17
# 44    1.0   22177.74       154806.14         28334.72
# 45    1.0    1000.23       124153.04          1903.93
# 46    1.0    1315.46       115816.21        297114.46
# 47    1.0       0.00       135426.92             0.00
# 48    1.0     542.05        51743.15             0.00
# 49    1.0       0.00       116983.80         45173.06

# %%
# Plot outputs
plt.scatter(X_test['Administration'], y_test,  color='black')
plt.scatter(X_test['Administration'], y_pred, color='blue')

plt.xticks(())
plt.yticks(())

plt.show()

# %%
X2['randnos']=np.random.normal(80,100,50)
X2
# Out:
#     const  R&D Spend  Administration  Marketing Spend     randnos
# 0     1.0  165349.20       136897.80        471784.10   10.017623
# 1     1.0  162597.70       151377.59        443898.53   43.167671
# 2     1.0  153441.51       101145.55        407934.54  -55.525835
# 3     1.0  144372.41       118671.85        383199.62   61.506817
# 4     1.0  142107.34        91391.77        366168.42   29.247903
# 5     1.0  131876.90        99814.71        362861.36   64.267463
# 6     1.0  134615.46       147198.87        127716.82  125.565609
# 7     1.0  130298.13       145530.06        323876.68   82.775800
# 8     1.0  120542.52       148718.95        311613.29  134.735388
# 9     1.0  123334.88       108679.17        304981.62   -4.990546
# 10    1.0  101913.08       110594.11        229160.95  158.374582
# 11    1.0  100671.96        91790.61        249744.55   97.529093
# 12    1.0   93863.75       127320.38        249839.44  109.424389
# 13    1.0   91992.39       135495.07        252664.93  254.934325
# 14    1.0  119943.24       156547.42        256512.92  140.651411
# 15    1.0  114523.61       122616.84        261776.23   -9.621485
# 16    1.0   78013.11       121597.55        264346.06   39.933814
# 17    1.0   94657.16       145077.58        282574.31  100.400977
# 18    1.0   91749.16       114175.79        294919.57    2.125671
# 19    1.0   86419.70       153514.11             0.00  168.233338
# 20    1.0   76253.86       113867.30        298664.47   43.062226
# 21    1.0   78389.47       153773.43        299737.29   77.543638
# 22    1.0   73994.56       122782.75        303319.26  -18.310931
# 23    1.0   67532.53       105751.03        304768.73  -89.314511
# 24    1.0   77044.01        99281.34        140574.81  152.562204
# 25    1.0   64664.71       139553.16        137962.62  240.755431
# 26    1.0   75328.87       144135.98        134050.07  115.073431
# 27    1.0   72107.60       127864.55        353183.81  117.072981
# 28    1.0   66051.52       182645.56        118148.20  237.461539
# 29    1.0   65605.48       153032.06        107138.38  150.448972
# 30    1.0   61994.48       115641.28         91131.24  -28.663889
# 31    1.0   61136.38       152701.92         88218.23   -3.845678
# 32    1.0   63408.86       129219.61         46085.25 -144.527897
# 33    1.0   55493.95       103057.49        214634.81  197.140157
# 34    1.0   46426.07       157693.92        210797.67  205.425378
# 35    1.0   46014.02        85047.44        205517.64  151.188636
# 36    1.0   28663.76       127056.21        201126.82  124.477714
# 37    1.0   44069.95        51283.14        197029.42   97.601606
# 38    1.0   20229.59        65947.93        185265.10  226.003436
# 39    1.0   38558.51        82982.09        174999.30  -53.175695
# 40    1.0   28754.33       118546.05        172795.67  142.488398
# 41    1.0   27892.92        84710.77        164470.71   -0.254821
# 42    1.0   23640.93        96189.63        148001.11  -23.152131
# 43    1.0   15505.73       127382.30         35534.17   73.556006
# 44    1.0   22177.74       154806.14         28334.72  -22.479194
# 45    1.0    1000.23       124153.04          1903.93   49.663916
# 46    1.0    1315.46       115816.21        297114.46   22.270169
# 47    1.0       0.00       135426.92             0.00  148.186197
# 48    1.0     542.05        51743.15             0.00  142.836125
# 49    1.0       0.00       116983.80         45173.06   10.982156

# %%
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Profit   R-squared:                       0.953
# Model:                            OLS   Adj. R-squared:                  0.949
# Method:                 Least Squares   F-statistic:                     229.2
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):           2.68e-29
# Time:                        08:52:31   Log-Likelihood:                -524.10
# No. Observations:                  50   AIC:                             1058.
# Df Residuals:                      45   BIC:                             1068.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            4.941e+04   6492.671      7.611      0.000    3.63e+04    6.25e+04
# R&D Spend           0.8076      0.045     18.146      0.000       0.718       0.897
# Administration     -0.0400      0.051     -0.784      0.437      -0.143       0.063
# Marketing Spend     0.0291      0.016      1.792      0.080      -0.004       0.062
# randnos            22.6750     14.716      1.541      0.130      -6.965      52.315
# ==============================================================================
# Omnibus:                       13.608   Durbin-Watson:                   1.178
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               18.034
# Skew:                          -0.915   Prob(JB):                     0.000121
# Kurtosis:                       5.304   Cond. No.                     1.41e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.41e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Plot outputs
plt.scatter(X_test['R&D Spend'], y_test,  color='black')
plt.scatter(X_test['R&D Spend'], y_pred, color='blue')

plt.xticks(())
plt.yticks(())

plt.show()

# %%
X2
# Out:
#     const  R&D Spend  Administration  Marketing Spend
# 0     1.0  165349.20       136897.80        471784.10
# 1     1.0  162597.70       151377.59        443898.53
# 2     1.0  153441.51       101145.55        407934.54
# 3     1.0  144372.41       118671.85        383199.62
# 4     1.0  142107.34        91391.77        366168.42
# 5     1.0  131876.90        99814.71        362861.36
# 6     1.0  134615.46       147198.87        127716.82
# 7     1.0  130298.13       145530.06        323876.68
# 8     1.0  120542.52       148718.95        311613.29
# 9     1.0  123334.88       108679.17        304981.62
# 10    1.0  101913.08       110594.11        229160.95
# 11    1.0  100671.96        91790.61        249744.55
# 12    1.0   93863.75       127320.38        249839.44
# 13    1.0   91992.39       135495.07        252664.93
# 14    1.0  119943.24       156547.42        256512.92
# 15    1.0  114523.61       122616.84        261776.23
# 16    1.0   78013.11       121597.55        264346.06
# 17    1.0   94657.16       145077.58        282574.31
# 18    1.0   91749.16       114175.79        294919.57
# 19    1.0   86419.70       153514.11             0.00
# 20    1.0   76253.86       113867.30        298664.47
# 21    1.0   78389.47       153773.43        299737.29
# 22    1.0   73994.56       122782.75        303319.26
# 23    1.0   67532.53       105751.03        304768.73
# 24    1.0   77044.01        99281.34        140574.81
# 25    1.0   64664.71       139553.16        137962.62
# 26    1.0   75328.87       144135.98        134050.07
# 27    1.0   72107.60       127864.55        353183.81
# 28    1.0   66051.52       182645.56        118148.20
# 29    1.0   65605.48       153032.06        107138.38
# 30    1.0   61994.48       115641.28         91131.24
# 31    1.0   61136.38       152701.92         88218.23
# 32    1.0   63408.86       129219.61         46085.25
# 33    1.0   55493.95       103057.49        214634.81
# 34    1.0   46426.07       157693.92        210797.67
# 35    1.0   46014.02        85047.44        205517.64
# 36    1.0   28663.76       127056.21        201126.82
# 37    1.0   44069.95        51283.14        197029.42
# 38    1.0   20229.59        65947.93        185265.10
# 39    1.0   38558.51        82982.09        174999.30
# 40    1.0   28754.33       118546.05        172795.67
# 41    1.0   27892.92        84710.77        164470.71
# 42    1.0   23640.93        96189.63        148001.11
# 43    1.0   15505.73       127382.30         35534.17
# 44    1.0   22177.74       154806.14         28334.72
# 45    1.0    1000.23       124153.04          1903.93
# 46    1.0    1315.46       115816.21        297114.46
# 47    1.0       0.00       135426.92             0.00
# 48    1.0     542.05        51743.15             0.00
# 49    1.0       0.00       116983.80         45173.06

# %%
# ?sm.OLS

# %% [markdown]
# # Example - 2

# %%
dataset = pd.read_excel('RegressionExample.xlsx')

# %%
dataset
# Out:
#     Efficiency Score  Stress level  Depression Score
# 0                 59            35                30
# 1                 67            33                32
# 2                 54            42                39
# 3                 51            43                39
# 4                 70            24                22
# 5                 48            48                47
# 6                 49            53                57
# 7                 42            56                57
# 8                 51            46                47
# 9                 70            24                22
# 10                72            19                14
# 11                54            38                34
# 12                76            20                21
# 13                83            18                20
# 14                56            41                50
# 15                75            21                17
# 16                82            14                15
# 17                87            13                14
# 18                73            20                18
# 19                59            37                35
# 20                48            45                41
# 21                73            23                20
# 22                69            30                31
# 23                87             9                 8
# 24                88             7                 5

# %%
X = dataset.drop('Efficiency Score', axis =1 )
y = dataset['Efficiency Score']

# %%
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Efficiency Score   R-squared:                       0.978
# Model:                            OLS   Adj. R-squared:                  0.976
# Method:                 Least Squares   F-statistic:                     487.4
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):           6.05e-19
# Time:                        05:52:26   Log-Likelihood:                -53.300
# No. Observations:                  25   AIC:                             112.6
# Df Residuals:                      22   BIC:                             116.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               96.4461      1.087     88.736      0.000      94.192      98.700
# Stress level        -1.5671      0.150    -10.427      0.000      -1.879      -1.255
# Depression Score     0.5732      0.142      4.029      0.001       0.278       0.868
# ==============================================================================
# Omnibus:                        0.105   Durbin-Watson:                   2.414
# Prob(Omnibus):                  0.949   Jarque-Bera (JB):                0.057
# Skew:                          -0.063   Prob(JB):                        0.972
# Kurtosis:                       2.803   Cond. No.                         117.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Example -3

# %%
dataset = pd.read_excel('RegressionExample.xlsx',sheet_name=1)

# %%
dataset
# Out:
#      EducLev  YrHired  Gender  Salary
# 0          3       92       1  3200.0
# 1          1       81       0  3910.0
# 2          1       83       0  3320.0
# 3          2       87       0  3060.0
# 4          3       92       1  2900.0
# ..       ...      ...     ...     ...
# 203        3       61       1  9500.0
# 204        5       59       1  9700.0
# 205        5       63       1  8800.0
# 206        5       60       1  9400.0
# 207        5       62       0  3000.0
#
# [208 rows x 4 columns]

# %%
X = dataset.drop('Salary', axis =1 )
y = dataset['Salary']

# %%
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.631
# Model:                            OLS   Adj. R-squared:                  0.626
# Method:                 Least Squares   F-statistic:                     116.3
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):           6.06e-44
# Time:                        05:57:07   Log-Likelihood:                -1652.3
# No. Observations:                 208   AIC:                             3313.
# Df Residuals:                     204   BIC:                             3326.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.163e+04    590.602     19.684      0.000    1.05e+04    1.28e+04
# EducLev      309.3826     35.140      8.804      0.000     240.098     378.668
# YrHired     -102.6256      6.870    -14.938      0.000    -116.171     -89.080
# Gender       446.9546    109.474      4.083      0.000     231.109     662.800
# ==============================================================================
# Omnibus:                       32.319   Durbin-Watson:                   1.737
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              247.896
# Skew:                          -0.025   Prob(JB):                     1.48e-54
# Kurtosis:                       8.348   Cond. No.                     1.06e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.06e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X['randnos2'] = np.random.uniform(10,100,208)

# %%
X
# Out:
#      EducLev  YrHired  Gender    randnos   randnos2
# 0          3       92       1  18.282995  52.702200
# 1          1       81       0  59.081108  52.587858
# 2          1       83       0  20.187109  34.556484
# 3          2       87       0  64.912212  33.402187
# 4          3       92       1  64.530640  98.828035
# ..       ...      ...     ...        ...        ...
# 203        3       61       1  15.910717  19.416924
# 204        5       59       1  75.433048  80.413663
# 205        5       63       1  68.039335  40.398800
# 206        5       60       1  58.135670  47.028789
# 207        5       62       0  51.548247  81.604786
#
# [208 rows x 5 columns]

# %%
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.637
# Model:                            OLS   Adj. R-squared:                  0.628
# Method:                 Least Squares   F-statistic:                     71.03
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):           1.26e-42
# Time:                        05:59:02   Log-Likelihood:                -1650.6
# No. Observations:                 208   AIC:                             3313.
# Df Residuals:                     202   BIC:                             3333.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.172e+04    596.311     19.659      0.000    1.05e+04    1.29e+04
# EducLev      313.6872     35.192      8.914      0.000     244.296     383.079
# YrHired     -101.0751      6.895    -14.660      0.000    -114.670     -87.480
# Gender       480.9518    110.885      4.337      0.000     262.311     699.593
# randnos       -1.0575      1.932     -0.547      0.585      -4.867       2.752
# randnos2      -3.4767      1.923     -1.808      0.072      -7.268       0.315
# ==============================================================================
# Omnibus:                       30.379   Durbin-Watson:                   1.730
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              210.988
# Skew:                           0.020   Prob(JB):                     1.53e-46
# Kurtosis:                       7.934   Cond. No.                     1.47e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.47e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
